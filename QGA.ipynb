// %%
operation Rotate(q: Qubit[], angles: Double[]) : Unit {
    H(q[0]);
    Ry(angles[0], q[0]);
    
    H(q[1]);
    Ry(angles[1], q[1]);
    
    H(q[2]);
    Ry(angles[2], q[2]);
    
    H(q[3]);
    Ry(angles[3], q[3]);
}
// Out:
// Rotate

// %%
operation prepareInitAngles(genome: Int, count: Int) : Double[] {
    mutable all_angles = new Double[genome*count];
    for (index in 0 .. genome*count-1) {
        set all_angles[index] = RandomReal(2)*90.0*0.01745;
    }
    return all_angles;
}
// Out:
// prepareInitAngles

// %%
open Microsoft.Quantum.Extensions.Math;
open Microsoft.Quantum.Extensions.Convert;
operation Eval(x : Int) : Double{
    let y = AbsD((ToDouble (x)-5.0)/(2.0+Sin(ToDouble (x))));
//     Message($"Evaluated y = {y}");
    return y;
}
// Out:
// Eval

// %%
operation getFitness(member : Result[]) : Double{
    mutable a0 = 0;
    mutable a1 = 0;
    mutable a2 = 0;
    mutable a3 = 0;
    if (member[0]==One){
        set a0 = 1;
    }
    if (member[1]==One){
        set a1 = 1;
    }
    if (member[2]==One){
        set a2 = 1;
    }
    if (member[3]==One){
        set a3 = 1;
    }
    
    let x = 8*a0 + 4*a1 + 2*a2 + a3;
    Message($"x = {x}");
    return Eval(x);
}
// Out:
// getFitness

// %%
operation nextGen (genome: Int, count: Int, gen: Int) : Result[] {
    mutable winner_angles = new Double[genome];
    mutable all_angles = prepareInitAngles(genome, count);
    mutable r = new Result[genome*count];
    mutable winner_index = -1;
    mutable eval = 0.0;
    let delta_theta = 0.03141592653*2.0;
    
    using (population = Qubit[genome*count]){
        Rotate(population, all_angles);

        set winner_index = -1;
        set eval = 0.0;
        set r =  MultiM (population);
        for (index in 0 .. count-1) {
            let temp = [r[index], r[index+1], r[index+2], r[index+3]];
            let temp_eval = getFitness(temp);
            if (eval < temp_eval) {
                set eval = temp_eval;
                set winner_index = index;
                Message($"Winner is: {winner_index}");
            }
        }
        ResetAll(population);
    }
    
    for (generation in 0 .. gen) {
    Message($"all_anlges[0] = {all_angles[0]}");
        for (index in 0 .. count-1) {
            if (index != winner_index) {
                if (r[index] == One and r[winner_index] == Zero) {
                    set all_angles[index] = all_angles[index] - delta_theta;
                }
                if (r[index + 1] == One and r[winner_index + 1] == Zero) {
                    set all_angles[index + 1] = all_angles[index + 1] - delta_theta;
                }
                if (r[index + 2] == One and r[winner_index + 2] == Zero) {
                    set all_angles[index + 2] = all_angles[index + 2] - delta_theta;
                }
                if (r[index + 3] == One and r[winner_index + 3] == Zero) {
                    set all_angles[index + 3] = all_angles[index + 3] - delta_theta;
                }
                
                if (r[index] == Zero and r[winner_index] == One) {
                    set all_angles[index] = all_angles[index] + delta_theta;
                }
                if (r[index + 1] == Zero and r[winner_index + 1] == One) {
                    set all_angles[index + 1] = all_angles[index + 1] + delta_theta;
                }
                if (r[index + 2] == Zero and r[winner_index + 2] == One) {
                    set all_angles[index + 2] = all_angles[index + 2] + delta_theta;
                }
                if (r[index + 3] == Zero and r[winner_index + 3] == One) {
                    set all_angles[index + 3] = all_angles[index + 3] + delta_theta;
                }
            }
        }
        
        using (population = Qubit[genome*count]){
            Rotate(population, all_angles);

            set winner_index = -1;
            set eval = 0.0;
            set r =  MultiM (population);
            for (index in 0 .. count-1) {
                let temp = [r[index], r[index+1], r[index+2], r[index+3]];
                let temp_eval = getFitness(temp);
                if (eval < temp_eval) {
                    set eval = temp_eval;
                    set winner_index = index;
                }
            }
            ResetAll(population);
        }
    Message($"Winner is: {winner_index} and eval: {eval} and generation: {generation}");
    }
        
    Message($"Final Winner is: {winner_index}");
    return [r[winner_index], r[winner_index+1], r[winner_index+2], r[winner_index+3]];
}
// Out:
// D:/snippet:(79,87): warning QS2001: Extra semicolon will be ignored.
// nextGen

// %%
operation QGA() : Result[] {
    return nextGen(4, 1, 150);
}
// Out:
// QGA

// %%
%simulate QGA
// Out:
// x = 0
// Winner is: 0
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 0
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 1
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 2
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 3
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 4
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 5
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 6
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 7
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 8
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 9
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 10
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 11
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 12
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 13
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 14
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 15
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 16
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 17
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 18
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 19
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 20
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 21
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 22
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 23
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 24
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 25
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 26
// all_anlges[0] = 0
// x = 2
// Winner is: 0 and eval: 1.03117679627321 and generation: 27
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 28
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 29
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 30
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 31
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 32
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 33
// all_anlges[0] = 0
// x = 2
// Winner is: 0 and eval: 1.03117679627321 and generation: 34
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 35
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 36
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 37
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 38
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 39
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 40
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 41
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 42
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 43
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 44
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 45
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 46
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 47
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 48
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 49
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 50
// all_anlges[0] = 0
// x = 2
// Winner is: 0 and eval: 1.03117679627321 and generation: 51
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 52
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 53
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 54
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 55
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 56
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 57
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 58
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 59
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 60
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 61
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 62
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 63
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 64
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 65
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 66
// all_anlges[0] = 0
// x = 2
// Winner is: 0 and eval: 1.03117679627321 and generation: 67
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 68
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 69
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 70
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 71
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 72
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 73
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 74
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 75
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 76
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 77
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 78
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 79
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 80
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 81
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 82
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 83
// all_anlges[0] = 0
// x = 2
// Winner is: 0 and eval: 1.03117679627321 and generation: 84
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 85
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 86
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 87
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 88
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 89
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 90
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 91
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 92
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 93
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 94
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 95
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 96
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 97
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 98
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 99
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 100
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 101
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 102
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 103
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 104
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 105
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 106
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 107
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 108
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 109
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 110
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 111
// all_anlges[0] = 0
// x = 2
// Winner is: 0 and eval: 1.03117679627321 and generation: 112
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 113
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 114
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 115
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 116
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 117
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 118
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 119
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 120
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 121
// all_anlges[0] = 0
// x = 6
// Winner is: 0 and eval: 0.581197842333939 and generation: 122
// all_anlges[0] = 0
// x = 2
// Winner is: 0 and eval: 1.03117679627321 and generation: 123
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 124
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 125
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 126
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 127
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 128
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 129
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 130
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 131
// all_anlges[0] = 0
// x = 2
// Winner is: 0 and eval: 1.03117679627321 and generation: 132
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 133
// all_anlges[0] = 0
// x = 6
// Winner is: 0 and eval: 0.581197842333939 and generation: 134
// all_anlges[0] = 0
// x = 2
// Winner is: 0 and eval: 1.03117679627321 and generation: 135
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 136
// all_anlges[0] = 0
// x = 2
// Winner is: 0 and eval: 1.03117679627321 and generation: 137
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 138
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 139
// all_anlges[0] = 0
// x = 2
// Winner is: 0 and eval: 1.03117679627321 and generation: 140
// all_anlges[0] = 0
// x = 4
// Winner is: 0 and eval: 0.804377418894265 and generation: 141
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 142
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 143
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 144
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 145
// all_anlges[0] = 0
// x = 2
// Winner is: 0 and eval: 1.03117679627321 and generation: 146
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 147
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 148
// all_anlges[0] = 0
// x = 0
// Winner is: 0 and eval: 2.5 and generation: 149
// all_anlges[0] = 0
// x = 2
// Winner is: 0 and eval: 1.03117679627321 and generation: 150
// Final Winner is: 0
// Zero, Zero, One, Zero
